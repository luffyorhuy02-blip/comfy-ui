# %% [markdown]
# # 🎨 ComfyUI FULL + comfyui.maymoc.shop
#
# **Đã cấu hình sẵn:**
# - ✅ Cloudflare Tunnel + Domain
# - ✅ Keep Alive chống tự tắt
# - ✅ **FULL Custom Nodes phổ biến**
# - ✅ Lưu vào Google Drive
#
# **Chạy lần lượt từ 1→9!**

# %%
#@title 1️⃣ 🔄 KEEP ALIVE
import time, random, threading, subprocess, gc
from IPython.display import display, Javascript

display(Javascript('''
(function() {
    let count = 0;
    const activities = [
        () => document.querySelector("colab-connect-button")?.click(),
        () => window.scrollBy(0, Math.random()*50-25),
        () => document.dispatchEvent(new MouseEvent('mousemove', {clientX: Math.random()*window.innerWidth, clientY: Math.random()*window.innerHeight})),
        () => document.querySelector("#output-area")?.click()
    ];
    function run() {
        count++;
        for(let i=0; i<3; i++) activities[Math.floor(Math.random()*activities.length)]();
        var el = document.getElementById('ka-indicator');
        if(el) el.innerHTML = '🔄 '+count;
        setTimeout(run, 20000 + Math.random()*20000);
    }
    var div = document.createElement('div'); div.id='ka-indicator';
    div.innerHTML = '🔄 ON';
    div.style.cssText = 'position:fixed;top:10px;right:10px;background:linear-gradient(135deg,#667eea,#764ba2);color:white;padding:10px 20px;border-radius:25px;font-size:13px;z-index:9999;';
    document.body.appendChild(div);
    run();
})();
'''))

def bg(): 
    while True: time.sleep(random.randint(30,90)); gc.collect()
threading.Thread(target=bg, daemon=True).start()
print("✅ KEEP ALIVE ACTIVATED!")

# %%
#@title 2️⃣ Kiểm tra GPU
# !nvidia-smi
import torch
print(f"\n✅ CUDA: {torch.cuda.is_available()} | GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")

# %%
#@title 3️⃣ Cài ComfyUI + Dependencies
# %cd /content
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# %cd ComfyUI
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install -q -r requirements.txt
# !pip install -q xformers
print("✅ ComfyUI installed!")

# %%
#@title 4️⃣ 📦 CÀI FULL CUSTOM NODES
# %cd /content/ComfyUI/custom_nodes

print("📦 Installing Custom Nodes...\n")

# === ESSENTIAL ===
print("🔧 [1/12] ComfyUI Manager...")
# !git clone -q https://github.com/ltdrdata/ComfyUI-Manager.git

print("🔧 [2/12] Impact Pack...")
# !git clone -q https://github.com/ltdrdata/ComfyUI-Impact-Pack.git

print("🔧 [3/12] Inspire Pack...")
# !git clone -q https://github.com/ltdrdata/ComfyUI-Inspire-Pack.git

# === CONTROLNET ===
print("🎮 [4/12] ControlNet Aux...")
# !git clone -q https://github.com/Fannovel16/comfyui_controlnet_aux.git

print("🎮 [5/12] Advanced ControlNet...")
# !git clone -q https://github.com/Kosinkadink/ComfyUI-Advanced-ControlNet.git

# === FACE & IMAGE ===
print("👤 [6/12] IPAdapter Plus...")
# !git clone -q https://github.com/cubiq/ComfyUI_IPAdapter_plus.git

print("👤 [7/12] Reactor (Face Swap)...")
# !git clone -q https://github.com/Gourieff/comfyui-reactor-node.git

print("👤 [8/12] Face Restore...")
# !git clone -q https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes.git

# === VIDEO & ANIMATION ===
print("🎬 [9/12] AnimateDiff Evolved...")
# !git clone -q https://github.com/Kosinkadink/ComfyUI-AnimateDiff-Evolved.git

print("🎬 [10/12] Video Helper Suite...")
# !git clone -q https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git

# === UTILITIES ===
print("⚡ [11/12] Efficiency Nodes...")
# !git clone -q https://github.com/jags111/efficiency-nodes-comfyui.git

print("⚡ [12/12] WAS Node Suite...")
# !git clone -q https://github.com/WASasquatch/was-node-suite-comfyui.git

print("\n📥 Installing dependencies...")
# !pip install -q -r comfyui_controlnet_aux/requirements.txt 2>/dev/null
# !pip install -q -r comfyui-reactor-node/requirements.txt 2>/dev/null
# !pip install -q -r was-node-suite-comfyui/requirements.txt 2>/dev/null
# !pip install -q insightface onnxruntime-gpu
# !pip install -q mediapipe
# !pip install -q opencv-python

print("\n" + "="*50)
print("✅ INSTALLED 12 CUSTOM NODE PACKAGES!")
print("="*50)
print("""
📦 Essential:
   • ComfyUI Manager
   • Impact Pack
   • Inspire Pack

🎮 ControlNet:
   • ControlNet Aux (preprocessors)
   • Advanced ControlNet

👤 Face & Style:
   • IPAdapter Plus
   • Reactor (Face Swap)
   • Comfyroll Nodes

🎬 Video:
   • AnimateDiff Evolved
   • Video Helper Suite

⚡ Utilities:
   • Efficiency Nodes
   • WAS Node Suite
""")

# %%
#@title 5️⃣ Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/ComfyUI/models/checkpoints
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/loras
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/vae
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/controlnet
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/ipadapter
# !mkdir -p /content/drive/MyDrive/ComfyUI/outputs

# !rm -rf /content/ComfyUI/models/checkpoints
# !rm -rf /content/ComfyUI/models/loras
# !rm -rf /content/ComfyUI/models/vae
# !rm -rf /content/ComfyUI/models/controlnet
# !rm -rf /content/ComfyUI/output

# !ln -s /content/drive/MyDrive/ComfyUI/models/checkpoints /content/ComfyUI/models/checkpoints
# !ln -s /content/drive/MyDrive/ComfyUI/models/loras /content/ComfyUI/models/loras
# !ln -s /content/drive/MyDrive/ComfyUI/models/vae /content/ComfyUI/models/vae
# !ln -s /content/drive/MyDrive/ComfyUI/models/controlnet /content/ComfyUI/models/controlnet
# !ln -s /content/drive/MyDrive/ComfyUI/outputs /content/ComfyUI/output

# IPAdapter models
# !mkdir -p /content/ComfyUI/models/ipadapter
# !ln -sf /content/drive/MyDrive/ComfyUI/models/ipadapter /content/ComfyUI/models/ipadapter

print("✅ Google Drive linked!")

# %%
#@title 6️⃣ Download Models (Tùy chọn)
download_sdxl = True  #@param {type:"boolean"}
download_sd15 = False  #@param {type:"boolean"}
download_controlnet = True  #@param {type:"boolean"}

# %cd /content/ComfyUI/models/checkpoints

if download_sdxl:
    print("📥 SDXL Base...")
    # !wget -q --show-progress -nc -O sd_xl_base_1.0.safetensors \
        "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors"

if download_sd15:
    print("📥 SD 1.5...")
    # !wget -q --show-progress -nc -O v1-5-pruned-emaonly.safetensors \
        "https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors"

if download_controlnet:
    print("📥 ControlNet models...")
    # %cd /content/ComfyUI/models/controlnet
    # !wget -q --show-progress -nc -O control-lora-canny-rank256.safetensors \
        "https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-canny-rank256.safetensors"
    # !wget -q --show-progress -nc -O control-lora-depth-rank256.safetensors \
        "https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-depth-rank256.safetensors"

print("\n✅ Models downloaded!")

# %%
#@title 7️⃣ Cài Cloudflare Tunnel
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb
print("✅ Cloudflared installed!")

# %%
#@title 8️⃣ 🚀 CHẠY COMFYUI
import subprocess, threading, time

# ============================================
# 🔧 ĐÃ CẤU HÌNH SẴN
# ============================================
CLOUDFLARE_TUNNEL_TOKEN = "eyJhIjoiZWYyMWQ3NTM2YTgwNGQ4ZjY1OTZlY2VmZjU3NzVkOTciLCJ0IjoiMjM2MTU3ZWQtYjc3NC00YmJlLTk5ZjctYWFjZDJiMmRmMWQyIiwicyI6Ik16TTROVEkwTldJdE5qSXlNQzAwWldNeUxUZ3lZemt0TXpNek5EZG1abUprWmpVeiJ9"
YOUR_DOMAIN = "comfyui.maymoc.shop"
# ============================================

def run_tunnel():
    subprocess.run(["cloudflared", "tunnel", "run", "--token", CLOUDFLARE_TUNNEL_TOKEN])

threading.Thread(target=run_tunnel, daemon=True).start()
time.sleep(5)

print("\n" + "="*60)
print(f"🌐 URL: https://{YOUR_DOMAIN}")
print("="*60)
print("✅ Keep Alive: ON")
print("✅ Cloudflare: CONNECTED")
print("✅ Custom Nodes: 12 packages")
print("="*60 + "\n")

# %cd /content/ComfyUI
# !python main.py --listen 0.0.0.0 --port 8188

# %% [markdown]
# ---
# ## ⬇️ Download thêm Models (Optional)

# %%
#@title [Optional] Download IPAdapter Models
# %cd /content/ComfyUI/models/ipadapter

print("📥 IPAdapter Plus SDXL...")
# !wget -q --show-progress -nc -O ip-adapter-plus_sdxl_vit-h.safetensors \
    "https://huggingface.co/h94/IP-Adapter/resolve/main/sdxl_models/ip-adapter-plus_sdxl_vit-h.safetensors"

print("📥 CLIP Vision...")
# !mkdir -p /content/ComfyUI/models/clip_vision
# %cd /content/ComfyUI/models/clip_vision
# !wget -q --show-progress -nc -O CLIP-ViT-H-14-laion2B-s32B-b79K.safetensors \
    "https://huggingface.co/h94/IP-Adapter/resolve/main/models/image_encoder/model.safetensors"

print("✅ IPAdapter models downloaded!")

# %%
#@title [Optional] Download AnimateDiff Models
# !mkdir -p /content/ComfyUI/models/animatediff_models
# %cd /content/ComfyUI/models/animatediff_models

print("📥 AnimateDiff v3...")
# !wget -q --show-progress -nc -O v3_sd15_adapter.ckpt \
    "https://huggingface.co/guoyww/animatediff/resolve/main/v3_sd15_adapter.ckpt"

print("✅ AnimateDiff models downloaded!")
